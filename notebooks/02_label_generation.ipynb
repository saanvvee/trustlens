# %% [markdown]
# # 02 - Teacher Label Generation
#
# Placeholder notebook. The actual labelling logic lives in `src/label_generator.py` (STEP 8); this notebook is for inspecting samples and rerunning small batches.
